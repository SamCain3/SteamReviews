# %% [markdown]
# _Sam's Test File_

# %%
# Import dependencies
import pandas as pd
import plotly.express as px

# %%
temp = pd.read_csv('Resources/steam_free_data.csv')
temp
# Out:
#                                      title  release_date  price  \
# 0         Counter-Strike: Global Offensive  Aug 21, 2012      0
# 1                            Apex Legends™   Nov 4, 2020      0
# 2                                 Lost Ark  Feb 11, 2022      0
# 3                                Destiny 2   Oct 1, 2019      0
# 4                              War Thunder  Aug 15, 2013      0
# 5                      PUBG: BATTLEGROUNDS  Dec 21, 2017      0
# 6                    Yu-Gi-Oh! Master Duel  Jan 18, 2022      0
# 7                                 Warframe  Mar 25, 2013      0
# 8                                   SMITE®   Sep 8, 2015      0
# 9                        World of Warships  Nov 15, 2017      0
# 10                                  Dota 2   Jul 9, 2013      0
# 11                           Halo Infinite  Nov 15, 2021      0
# 12                              Brawlhalla  Oct 17, 2017      0
# 13           STAR WARS™: The Old Republic™  Jul 21, 2020      0
# ...

# %%
action_games = temp[temp['genres'].str.contains('Action')]
action_games
# Out:
#                                      title  release_date  price  \
# 0         Counter-Strike: Global Offensive  Aug 21, 2012      0
# 1                            Apex Legends™   Nov 4, 2020      0
# 2                                 Lost Ark  Feb 11, 2022      0
# 3                                Destiny 2   Oct 1, 2019      0
# 4                              War Thunder  Aug 15, 2013      0
# 5                      PUBG: BATTLEGROUNDS  Dec 21, 2017      0
# 7                                 Warframe  Mar 25, 2013      0
# 8                                   SMITE®   Sep 8, 2015      0
# 9                        World of Warships  Nov 15, 2017      0
# 10                                  Dota 2   Jul 9, 2013      0
# 11                           Halo Infinite  Nov 15, 2021      0
# 12                              Brawlhalla  Oct 17, 2017      0
# 15                    World of Tanks Blitz   Nov 9, 2016      0
# 16                               Paladins®   May 8, 2018      0
# ...

# %%
casual_games = temp[temp['genres'].str.contains('Casual')]
casual_games
# Out:
#                     title  release_date  price  \
# 14                 VRChat   Feb 1, 2017      0
# 25               Rec Room   Sep 2, 2021      0
# 29  IdleOn - The Idle MMO   Apr 2, 2021      0
# 31            Crush Crush  Oct 18, 2016      0
# 38            Shop Titans   May 5, 2020      0
# 43               Unturned   Jul 7, 2017      0
# 44    Bloons TD Battles 2  Nov 30, 2021      0
# 47                  Trove   Jul 9, 2015      0
# 48    Super Animal Royale  Aug 26, 2021      0
#
#                                                  link average_review  \
# 14  https://store.steampowered.com/app/438100/VRCh...  Very Positive
# 25  https://store.steampowered.com/app/471710/Rec_...  Very Positive
# 29  https://store.steampowered.com/app/1476970/Idl...  Very Positive
# 31  https://store.steampowered.com/app/459820/Crus...  Very Positive
# 38  https://store.steampowered.com/app/1258080/Sho...          Mixed
# 43  https://store.steampowered.com/app/304930/Untu...  Very Positive
# ...
